# %%
import pandas as pd
messages = pd.read_csv("data/SMSSpamCollection.txt", sep="\t", names=["label", "message"])

# %%
messages.shape
# Out:
# (5572, 2)

# %%
messages.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
## Data cleaning & preprocessing
import re
import nltk
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/bhaveshg/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
corpus = []
for i in range(len(messages)):
    review = re.sub("[^a-zA-Z]", " ", messages["message"][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if word not in set(stopwords.words("english"))]
    review = " ".join(review)
    corpus.append(review)

corpus[:5]
# Out:
# ['go jurong point crazi avail bugi n great world la e buffet cine got amor wat',
#  'ok lar joke wif u oni',
#  'free entri wkli comp win fa cup final tkt st may text fa receiv entri question std txt rate c appli',
#  'u dun say earli hor u c alreadi say',
#  'nah think goe usf live around though']

# %%
## Creating the Bag of Words
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=100, binary=True)

# %%
cv.fit(corpus)
X = cv.transform(corpus).toarray()
X.shape
# Out:
# (5572, 100)

# %%
cv.vocabulary_
# Out:
# {'go': np.int64(22),
#  'great': np.int64(25),
#  'got': np.int64(24),
#  'wat': np.int64(90),
#  'ok': np.int64(56),
#  'free': np.int64(18),
#  'win': np.int64(94),
#  'text': np.int64(77),
#  'txt': np.int64(85),
#  'say': np.int64(67),
#  'alreadi': np.int64(0),
#  'think': np.int64(80),
#  'hey': np.int64(28),
#  'week': np.int64(92),
#  'back': np.int64(3),
#  'like': np.int64(38),
#  'still': np.int64(73),
#  'send': np.int64(69),
#  'even': np.int64(15),
#  'friend': np.int64(19),
#  'prize': np.int64(62),
#  'claim': np.int64(7),
#  'call': np.int64(4),
#  'mobil': np.int64(47),
#  'co': np.int64(8),
#  'home': np.int64(30),
#  'want': np.int64(89),
#  'today': np.int64(82),
#  'cash': np.int64(6),
#  'day': np.int64(12),
#  'repli': np.int64(64),
#  'www': np.int64(96),
#  'right': np.int64(65),
#  'thank': np.int64(78),
#  'take': np.int64(75),
#  'time': np.int64(81),
#  'use': np.int64(87),
#  'messag': np.int64(44),
#  'oh': np.int64(55),
#  'ye': np.int64(97),
#  'make': np.int64(42),
#  'way': np.int64(91),
#  'feel': np.int64(16),
#  'dont': np.int64(14),
#  'miss': np.int64(46),
#  'ur': np.int64(86),
#  'tri': np.int64(84),
#  'da': np.int64(11),
#  'lor': np.int64(39),
#  'meet': np.int64(43),
#  'realli': np.int64(63),
#  'get': np.int64(20),
#  'know': np.int64(33),
#  'love': np.int64(40),
#  'let': np.int64(37),
#  'work': np.int64(95),
#  'wait': np.int64(88),
#  'yeah': np.int64(98),
#  'tell': np.int64(76),
#  'pleas': np.int64(61),
#  'msg': np.int64(49),
#  'see': np.int64(68),
#  'pl': np.int64(60),
#  'need': np.int64(51),
#  'tomorrow': np.int64(83),
#  'hope': np.int64(31),
#  'well': np.int64(93),
#  'lt': np.int64(41),
#  'gt': np.int64(26),
#  'ask': np.int64(1),
#  'morn': np.int64(48),
#  'happi': np.int64(27),
#  'sorri': np.int64(72),
#  'give': np.int64(21),
#  'new': np.int64(52),
#  'find': np.int64(17),
#  'year': np.int64(99),
#  'later': np.int64(35),
#  'pick': np.int64(59),
#  'good': np.int64(23),
#  'come': np.int64(9),
#  'said': np.int64(66),
#  'hi': np.int64(29),
#  'babe': np.int64(2),
#  'im': np.int64(32),
#  'much': np.int64(50),
#  'stop': np.int64(74),
#  'one': np.int64(57),
#  'night': np.int64(53),
#  'servic': np.int64(70),
#  'dear': np.int64(13),
#  'thing': np.int64(79),
#  'contact': np.int64(10),
#  'last': np.int64(34),
#  'min': np.int64(45),
#  'number': np.int64(54),
#  'leav': np.int64(36),
#  'sleep': np.int64(71),
#  'care': np.int64(5),
#  'phone': np.int64(58)}

# %%
## N-Gram model example
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=100, binary=True, ngram_range=(1, 1))
cv.fit(corpus)
X = cv.transform(corpus).toarray()

# %%
cv.vocabulary_
# Out:
# {'go': np.int64(22),
#  'great': np.int64(25),
#  'got': np.int64(24),
#  'wat': np.int64(90),
#  'ok': np.int64(56),
#  'free': np.int64(18),
#  'win': np.int64(94),
#  'text': np.int64(77),
#  'txt': np.int64(85),
#  'say': np.int64(67),
#  'alreadi': np.int64(0),
#  'think': np.int64(80),
#  'hey': np.int64(28),
#  'week': np.int64(92),
#  'back': np.int64(3),
#  'like': np.int64(38),
#  'still': np.int64(73),
#  'send': np.int64(69),
#  'even': np.int64(15),
#  'friend': np.int64(19),
#  'prize': np.int64(62),
#  'claim': np.int64(7),
#  'call': np.int64(4),
#  'mobil': np.int64(47),
#  'co': np.int64(8),
#  'home': np.int64(30),
#  'want': np.int64(89),
#  'today': np.int64(82),
#  'cash': np.int64(6),
#  'day': np.int64(12),
#  'repli': np.int64(64),
#  'www': np.int64(96),
#  'right': np.int64(65),
#  'thank': np.int64(78),
#  'take': np.int64(75),
#  'time': np.int64(81),
#  'use': np.int64(87),
#  'messag': np.int64(44),
#  'oh': np.int64(55),
#  'ye': np.int64(97),
#  'make': np.int64(42),
#  'way': np.int64(91),
#  'feel': np.int64(16),
#  'dont': np.int64(14),
#  'miss': np.int64(46),
#  'ur': np.int64(86),
#  'tri': np.int64(84),
#  'da': np.int64(11),
#  'lor': np.int64(39),
#  'meet': np.int64(43),
#  'realli': np.int64(63),
#  'get': np.int64(20),
#  'know': np.int64(33),
#  'love': np.int64(40),
#  'let': np.int64(37),
#  'work': np.int64(95),
#  'wait': np.int64(88),
#  'yeah': np.int64(98),
#  'tell': np.int64(76),
#  'pleas': np.int64(61),
#  'msg': np.int64(49),
#  'see': np.int64(68),
#  'pl': np.int64(60),
#  'need': np.int64(51),
#  'tomorrow': np.int64(83),
#  'hope': np.int64(31),
#  'well': np.int64(93),
#  'lt': np.int64(41),
#  'gt': np.int64(26),
#  'ask': np.int64(1),
#  'morn': np.int64(48),
#  'happi': np.int64(27),
#  'sorri': np.int64(72),
#  'give': np.int64(21),
#  'new': np.int64(52),
#  'find': np.int64(17),
#  'year': np.int64(99),
#  'later': np.int64(35),
#  'pick': np.int64(59),
#  'good': np.int64(23),
#  'come': np.int64(9),
#  'said': np.int64(66),
#  'hi': np.int64(29),
#  'babe': np.int64(2),
#  'im': np.int64(32),
#  'much': np.int64(50),
#  'stop': np.int64(74),
#  'one': np.int64(57),
#  'night': np.int64(53),
#  'servic': np.int64(70),
#  'dear': np.int64(13),
#  'thing': np.int64(79),
#  'contact': np.int64(10),
#  'last': np.int64(34),
#  'min': np.int64(45),
#  'number': np.int64(54),
#  'leav': np.int64(36),
#  'sleep': np.int64(71),
#  'care': np.int64(5),
#  'phone': np.int64(58)}

# %%
## N-Gram model example
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=500, binary=True, ngram_range=(1, 2))
cv.fit(corpus)
X = cv.transform(corpus).toarray()

# %%
cv.vocabulary_
# Out:
# {'go': np.int64(155),
#  'point': np.int64(332),
#  'great': np.int64(165),
#  'world': np.int64(483),
#  'got': np.int64(163),
#  'wat': np.int64(463),
#  'ok': np.int64(297),
#  'lar': np.int64(216),
#  'wif': np.int64(473),
#  'free': np.int64(142),
#  'entri': np.int64(126),
#  'win': np.int64(475),
#  'final': np.int64(135),
#  'st': np.int64(399),
#  'may': np.int64(252),
#  'text': np.int64(414),
#  'receiv': np.int64(353),
#  'question': np.int64(344),
#  'txt': np.int64(445),
#  'rate': np.int64(346),
#  'appli': np.int64(18),
#  'dun': np.int64(115),
#  'say': np.int64(367),
#  'earli': np.int64(117),
#  'alreadi': np.int64(9),
#  'think': np.int64(420),
#  'goe': np.int64(157),
#  'live': np.int64(234),
#  'around': np.int64(20),
#  'though': np.int64(422),
#  'hey': np.int64(187),
#  'week': np.int64(466),
#  'word': np.int64(481),
#  'back': np.int64(29),
#  'like': np.int64(230),
#  'fun': np.int64(149),
#  'still': np.int64(402),
#  'xxx': np.int64(490),
#  'send': np.int64(375),
#  'even': np.int64(127),
#  'brother': np.int64(46),
#  'speak': np.int64(397),
#  'per': np.int64(313),
#  'set': np.int64(379),
#  'friend': np.int64(144),
#  'network': np.int64(280),
#  'custom': np.int64(87),
#  'select': np.int64(373),
#  'prize': np.int64(339),
#  'claim': np.int64(67),
#  'call': np.int64(51),
#  'code': np.int64(73),
#  'valid': np.int64(453),
#  'hour': np.int64(194),
#  'claim call': np.int64(68),
#  'mobil': np.int64(263),
#  'month': np.int64(266),
#  'updat': np.int64(448),
#  'latest': np.int64(220),
#  'colour': np.int64(75),
#  'camera': np.int64(55),
#  'co': np.int64(71),
#  'free call': np.int64(143),
#  'gonna': np.int64(159),
#  'home': np.int64(191),
#  'soon': np.int64(393),
#  'want': np.int64(462),
#  'talk': np.int64(411),
#  'stuff': np.int64(405),
#  'tonight': np.int64(433),
#  'enough': np.int64(124),
#  'today': np.int64(428),
#  'chanc': np.int64(61),
#  'cash': np.int64(59),
#  'pound': np.int64(335),
#  'cost': np.int64(82),
#  'day': np.int64(93),
#  'repli': np.int64(355),
#  'info': np.int64(204),
#  'chanc win': np.int64(62),
#  'urgent': np.int64(450),
#  'www': np.int64(487),
#  'net': np.int64(279),
#  'pobox': np.int64(331),
#  'search': np.int64(370),
#  'right': np.int64(356),
#  'thank': np.int64(416),
#  'wont': np.int64(480),
#  'take': np.int64(409),
#  'help': np.int64(186),
#  'wonder': np.int64(479),
#  'time': np.int64(426),
#  'date': np.int64(92),
#  'use': np.int64(452),
#  'credit': np.int64(85),
#  'next': np.int64(285),
#  'messag': np.int64(256),
#  'http': np.int64(197),
#  'com': np.int64(76),
#  'oh': np.int64(296),
#  'watch': np.int64(464),
#  'rememb': np.int64(354),
#  'name': np.int64(274),
#  'ye': np.int64(492),
#  'make': np.int64(248),
#  'fine': np.int64(137),
#  'way': np.int64(465),
#  'feel': np.int64(134),
#  'dont': np.int64(107),
#  'miss': np.int64(261),
#  'news': np.int64(284),
#  'ur': np.int64(449),
#  'nation': np.int64(275),
#  'tri': np.int64(439),
#  'pay': np.int64(311),
#  'first': np.int64(139),
#  'da': np.int64(89),
#  'finish': np.int64(138),
#  'lunch': np.int64(244),
#  'lor': np.int64(238),
#  'ard': np.int64(19),
#  'alright': np.int64(10),
#  'meet': np.int64(255),
#  'eat': np.int64(119),
#  'realli': np.int64(351),
#  'get': np.int64(151),
#  'worri': np.int64(484),
#  'know': np.int64(213),
#  'lol': np.int64(235),
#  'alway': np.int64(12),
#  'bu': np.int64(48),
#  'mom': np.int64(264),
#  'left': np.int64(222),
#  'dinner': np.int64(105),
#  'love': np.int64(240),
#  'amp': np.int64(13),
#  'car': np.int64(57),
#  'let': np.int64(226),
#  'room': np.int64(359),
#  'let know': np.int64(227),
#  'work': np.int64(482),
#  'wait': np.int64(457),
#  'sure': np.int64(407),
#  'us': np.int64(451),
#  'yeah': np.int64(493),
#  'till': np.int64(425),
#  'tell': np.int64(412),
#  'anyth': np.int64(16),
#  'rington': np.int64(358),
#  'uk': np.int64(446),
#  'charg': np.int64(64),
#  'pleas': np.int64(324),
#  'yup': np.int64(499),
#  'look': np.int64(237),
#  'msg': np.int64(269),
#  'nd': np.int64(277),
#  'lesson': np.int64(225),
#  'done': np.int64(106),
#  'see': np.int64(372),
#  'decid': np.int64(96),
#  'hello': np.int64(185),
#  'invit': np.int64(206),
#  'pl': np.int64(318),
#  'weekend': np.int64(467),
#  'need': np.int64(278),
#  'sweet': np.int64(408),
#  'sm': np.int64(389),
#  'nokia': np.int64(290),
#  'deliveri': np.int64(99),
#  'tomorrow': np.int64(431),
#  'pleas call': np.int64(325),
#  'hope': np.int64(192),
#  'man': np.int64(249),
#  'well': np.int64(469),
#  'lt': np.int64(241),
#  'gt': np.int64(166),
#  'lt gt': np.int64(243),
#  'could': np.int64(83),
#  'mayb': np.int64(253),
#  'ask': np.int64(21),
#  'bit': np.int64(39),
#  'saw': np.int64(366),
#  'class': np.int64(69),
#  'run': np.int64(361),
#  'half': np.int64(176),
#  'second': np.int64(371),
#  'morn': np.int64(267),
#  'place': np.int64(320),
#  'never': np.int64(281),
#  'thought': np.int64(423),
#  'sinc': np.int64(386),
#  'best': np.int64(35),
#  'happi': np.int64(179),
#  'sorri': np.int64(394),
#  'give': np.int64(154),
#  'offer': np.int64(294),
#  'new': np.int64(282),
#  'play': np.int64(322),
#  'end': np.int64(122),
#  'yesterday': np.int64(495),
#  'find': np.int64(136),
#  'year': np.int64(494),
#  'special': np.int64(398),
#  'pm': np.int64(328),
#  'later': np.int64(219),
#  'sorri call': np.int64(395),
#  'call later': np.int64(53),
#  'reach': np.int64(347),
#  'pick': np.int64(317),
#  'pain': np.int64(309),
#  'good': np.int64(160),
#  'girl': np.int64(153),
#  'part': np.int64(310),
#  'check': np.int64(66),
#  'come': np.int64(77),
#  'doubl': np.int64(108),
#  'hair': np.int64(175),
#  'said': np.int64(364),
#  'nice': np.int64(286),
#  'mob': np.int64(262),
#  'award': np.int64(25),
#  'bonu': np.int64(40),
#  'frnd': np.int64(146),
#  'trip': np.int64(441),
#  'di': np.int64(102),
#  'hear': np.int64(183),
#  'money': np.int64(265),
#  'hi': np.int64(188),
#  'babe': np.int64(27),
#  'im': np.int64(202),
#  'wanna': np.int64(461),
#  'someth': np.int64(392),
#  'xx': np.int64(489),
#  'that': np.int64(418),
#  'cool': np.int64(81),
#  'peopl': np.int64(312),
#  'much': np.int64(270),
#  'pa': np.int64(308),
#  'job': np.int64(207),
#  'ah': np.int64(7),
#  'stop': np.int64(403),
#  'real': np.int64(350),
#  'yo': np.int64(497),
#  'one': np.int64(301),
#  'start': np.int64(400),
#  'came': np.int64(54),
#  'bed': np.int64(33),
#  'wen': np.int64(470),
#  'close': np.int64(70),
#  'anoth': np.int64(14),
#  'night': np.int64(287),
#  'late': np.int64(218),
#  'afternoon': np.int64(5),
#  'mean': np.int64(254),
#  'smile': np.int64(390),
#  'hurt': np.int64(199),
#  'someon': np.int64(391),
#  'servic': np.int64(378),
#  'guarante': np.int64(168),
#  'custom servic': np.int64(88),
#  'havent': np.int64(181),
#  'plan': np.int64(321),
#  'buy': np.int64(50),
#  'show': np.int64(384),
#  'collect': np.int64(74),
#  'po': np.int64(329),
#  'box': np.int64(43),
#  'po box': np.int64(330),
#  'movi': np.int64(268),
#  'abt': np.int64(1),
#  'wk': np.int64(478),
#  'forgot': np.int64(141),
#  'caus': np.int64(60),
#  'noth': np.int64(291),
#  'els': np.int64(121),
#  'okay': np.int64(299),
#  'price': np.int64(337),
#  'long': np.int64(236),
#  'drive': np.int64(112),
#  'test': np.int64(413),
#  'yet': np.int64(496),
#  'guess': np.int64(171),
#  'chang': np.int64(63),
#  'life': np.int64(229),
#  'lot': np.int64(239),
#  'dear': np.int64(95),
#  'wish': np.int64(476),
#  'birthday': np.int64(38),
#  'aight': np.int64(8),
#  'would': np.int64(486),
#  'address': np.int64(4),
#  'old': np.int64(300),
#  'better': np.int64(36),
#  'busi': np.int64(49),
#  'thing': np.int64(419),
#  'contact': np.int64(80),
#  'last': np.int64(217),
#  'draw': np.int64(109),
#  'hr': np.int64(196),
#  'ppm': np.int64(336),
#  'tri contact': np.int64(440),
#  'prize guarante': np.int64(340),
#  'guarante call': np.int64(169),
#  'valid hr': np.int64(454),
#  'anyway': np.int64(17),
#  'juz': np.int64(210),
#  'haha': np.int64(174),
#  'happen': np.int64(178),
#  'enter': np.int64(125),
#  'went': np.int64(471),
#  'holiday': np.int64(190),
#  'min': np.int64(258),
#  'select receiv': np.int64(374),
#  'must': np.int64(273),
#  'inform': np.int64(205),
#  'school': np.int64(369),
#  'food': np.int64(140),
#  'account': np.int64(2),
#  'landlin': np.int64(215),
#  'call landlin': np.int64(52),
#  'number': np.int64(293),
#  'sent': np.int64(377),
#  'answer': np.int64(15),
#  'top': np.int64(434),
#  'player': np.int64(323),
#  'join': np.int64(208),
#  'bt': np.int64(47),
#  'nt': np.int64(292),
#  'haf': np.int64(173),
#  'chat': np.int64(65),
#  'age': np.int64(6),
#  'yr': np.int64(498),
#  'sir': np.int64(387),
#  'mail': np.int64(247),
#  'littl': np.int64(233),
#  'person': np.int64(314),
#  'coz': np.int64(84),
#  'heart': np.int64(184),
#  'gud': np.int64(170),
#  'open': np.int64(303),
#  'ya': np.int64(491),
#  'sexi': np.int64(380),
#  'luv': np.int64(245),
#  'thk': np.int64(421),
#  'dream': np.int64(110),
#  'without': np.int64(477),
#  'tv': np.int64(443),
#  'leav': np.int64(221),
#  'hous': np.int64(195),
#  'boy': np.int64(44),
#  'new year': np.int64(283),
#  'keep': np.int64(211),
#  'hand': np.int64(177),
#  'send stop': np.int64(376),
#  'order': np.int64(306),
#  'complet': np.int64(79),
#  'also': np.int64(11),
#  'liao': np.int64(228),
#  'cant': np.int64(56),
#  'believ': np.int64(34),
#  'ill': np.int64(201),
#  'bath': np.int64(31),
#  'stay': np.int64(401),
#  'til': np.int64(424),
#  'gr': np.int64(164),
#  'guy': np.int64(172),
#  'minut': np.int64(260),
#  'xma': np.int64(488),
#  'ju': np.int64(209),
#  'si': np.int64(385),
#  'th': np.int64(415),
#  'co uk': np.int64(72),
#  'touch': np.int64(436),
#  'abl': np.int64(0),
#  'everi': np.int64(129),
#  'hav': np.int64(180),
#  'stori': np.int64(404),
#  'tmr': np.int64(427),
#  'decim': np.int64(97),
#  'id': np.int64(200),
#  'lt decim': np.int64(242),
#  'decim gt': np.int64(98),
#  'sleep': np.int64(388),
#  'dat': np.int64(91),
#  'oso': np.int64(307),
#  'big': np.int64(37),
#  'readi': np.int64(349),
#  'noe': np.int64(289),
#  'leh': np.int64(223),
#  'sound': np.int64(396),
#  'head': np.int64(182),
#  'easi': np.int64(118),
#  'import': np.int64(203),
#  'shop': np.int64(383),
#  'nite': np.int64(288),
#  'optout': np.int64(304),
#  'good morn': np.int64(161),
#  'walk': np.int64(459),
#  'die': np.int64(104),
#  'told': np.int64(430),
#  'face': np.int64(132),
#  'thanx': np.int64(417),
#  'everyth': np.int64(131),
#  'didnt': np.int64(103),
#  'wake': np.int64(458),
#  'good night': np.int64(162),
#  'voucher': np.int64(456),
#  'gift': np.int64(152),
#  'music': np.int64(272),
#  'hold': np.int64(189),
#  'wid': np.int64(472),
#  'true': np.int64(442),
#  'care': np.int64(58),
#  'video': np.int64(455),
#  'ring': np.int64(357),
#  'hot': np.int64(193),
#  'unsubscrib': np.int64(447),
#  'might': np.int64(257),
#  'full': np.int64(148),
#  'babi': np.int64(28),
#  'shall': np.int64(381),
#  'phone': np.int64(315),
#  'plz': np.int64(327),
#  'pl send': np.int64(319),
#  'shit': np.int64(382),
#  'book': np.int64(41),
#  'friendship': np.int64(145),
#  'game': np.int64(150),
#  'tone': np.int64(432),
#  'weekli': np.int64(468),
#  'cs': np.int64(86),
#  'wot': np.int64(485),
#  'made': np.int64(246),
#  'dunno': np.int64(116),
#  'dude': np.int64(114),
#  'kiss': np.int64(212),
#  'problem': np.int64(342),
#  'read': np.int64(348),
#  'line': np.int64(231),
#  'post': np.int64(334),
#  'two': np.int64(444),
#  'ever': np.int64(128),
#  'suit': np.int64(406),
#  'land': np.int64(214),
#  'row': np.int64(360),
#  'take care': np.int64(410),
#  'orang': np.int64(305),
#  'gt min': np.int64(167),
#  'bring': np.int64(45),
#  'quit': np.int64(345),
#  'reason': np.int64(352),
#  'huh': np.int64(198),
#  'sat': np.int64(365),
#  'offic': np.int64(295),
#  'actual': np.int64(3),
#  'put': np.int64(343),
#  'god': np.int64(156),
#  'poli': np.int64(333),
#  'drink': np.int64(111),
#  'den': np.int64(100),
#  'mind': np.int64(259),
#  'fuck': np.int64(147),
#  'tot': np.int64(435),
#  'detail': np.int64(101),
#  'beauti': np.int64(32),
#  'bad': np.int64(30),
#  'princess': np.int64(338),
#  'enjoy': np.int64(123),
#  'mani': np.int64(250),
#  'sae': np.int64(363),
#  'either': np.int64(120),
#  'bore': np.int64(42),
#  'attempt': np.int64(22),
#  'probabl': np.int64(341),
#  'listen': np.int64(232),
#  'onlin': np.int64(302),
#  'pic': np.int64(316),
#  'mum': np.int64(271),
#  'sch': np.int64(368),
#  'wife': np.int64(474),
#  'train': np.int64(438),
#  'ok lor': np.int64(298),
#  'famili': np.int64(133),
#  'togeth': np.int64(429),
#  'dad': np.int64(90),
#  'town': np.int64(437),
#  'de': np.int64(94),
#  'everi week': np.int64(130),
#  'come home': np.int64(78),
#  'away': np.int64(26),
#  'goin': np.int64(158),
#  'nation rate': np.int64(276),
#  'mate': np.int64(251),
#  'await': np.int64(23),
#  'await collect': np.int64(24),
#  'wan': np.int64(460),
#  'drop': np.int64(113),
#  'sad': np.int64(362),
#  'plu': np.int64(326),
#  'lei': np.int64(224)}

# %%
X.shape
# Out:
# (5572, 500)
